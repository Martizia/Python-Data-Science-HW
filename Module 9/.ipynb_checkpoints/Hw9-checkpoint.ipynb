# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt

# %%
# Завантаження датасету Fashion MNIST
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
# Нормалізація зображень до діапазону [0, 1]
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Додавання каналу для зображень (оскільки це чорно-білі зображення, канал один)
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))

# %%
# Перетворення міток у формат one-hot encoding
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# Створення моделі
model = models.Sequential()
model.add(layers.Flatten(input_shape=(28, 28, 1))) 
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='sigmoid'))

# %%
# Компіляція моделі
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Тренування моделі
history = model.fit(train_images, train_labels, epochs=30, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/30
# 2024-07-12 19:45:25.314568: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 150528000 exceeds 10% of free system memory.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6209 - loss: 1.0703 - val_accuracy: 0.8329 - val_loss: 0.4549
# Epoch 2/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8106 - loss: 0.5306 - val_accuracy: 0.8488 - val_loss: 0.4096
# Epoch 3/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8383 - loss: 0.4583 - val_accuracy: 0.8598 - val_loss: 0.3903
# Epoch 4/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8483 - loss: 0.4272 - val_accuracy: 0.8684 - val_loss: 0.3648
# Epoch 5/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8591 - loss: 0.3961 - val_accuracy: 0.8715 - val_loss: 0.3526
# Epoch 6/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8600 - loss: 0.3850 - val_accuracy: 0.8747 - val_loss: 0.3433
# Epoch 7/30
# ...

# %%
# Оцінка моделі на тестових даних
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8842 - loss: 0.3370
# Test accuracy: 0.8852999806404114

# %%
# Витягуємо дані про точність та втрати з історії тренування
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_acc) + 1)

# Будуємо графік точності
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_acc, 'bo-', label='Training accuracy')
plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# Будуємо графік втрат
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'bo-', label='Training loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Висновок

# %% [markdown]
# Для побудови нейронної мережі було використано 6 шарів: один шар Flatten, чотири Dense шари та два шари Dropout.
# Шари Dence використані для регуляризації моделі - "виключення" (встановлення в нуль) 30% нейронів в процесі навчання моделі.
#
# Також були підібрані наступні гіперпараметри: функція активації - Sigmoid, оптимізатор - Adam, кількість епох - 30, розмір батчу - 128.
#
# Точність моделі сстановить 0,89 (0.8852999806404114).
