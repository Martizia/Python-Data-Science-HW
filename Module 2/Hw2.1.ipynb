# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8'
birth_rate_table = pd.read_html(url, match='Коефіцієнт народжуваності в регіонах України', decimal=',', thousands='.')[0]
birth_rate_table
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6     —     —
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2     —
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1     —
# 12          Львівська  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13       Миколаївська  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14            Одеська  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15         Полтавська  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16         Рівненська  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17            Сумська  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18      Тернопільська  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19         Харківська  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20         Херсонська  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21        Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22          Черкаська  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23        Чернівецька  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24       Чернігівська  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25               Київ   NaN  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26        Севастополь   NaN   NaN   NaN  12.5   7.0  12.0     —     —
# 27            Україна  22.8  20.5  15.2  12.6   7.8  11.4  11.1   8.1

# %%
birth_rate_table.shape
# Out:
# (28, 9)

# %%
birth_rate_table.replace('—', np.nan, inplace=True)
birth_rate_table
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# 12          Львівська  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13       Миколаївська  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14            Одеська  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15         Полтавська  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16         Рівненська  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17            Сумська  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18      Тернопільська  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19         Харківська  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20         Херсонська  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21        Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22          Черкаська  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23        Чернівецька  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24       Чернігівська  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25               Київ   NaN  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26        Севастополь   NaN   NaN   NaN  12.5   7.0  12.0   NaN   NaN
# 27            Україна  22.8  20.5  15.2  12.6   7.8  11.4  11.1   8.1

# %%
birth_rate_table.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014       object
# 2019       object
# dtype: object

# %%
columns_to_convert = ['2014', '2019']
birth_rate_table[columns_to_convert] = birth_rate_table[columns_to_convert].apply(pd.to_numeric, errors='coerce')
birth_rate_table.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014      float64
# 2019      float64
# dtype: object

# %%
missing_percentages = (birth_rate_table.isnull().sum() / len(birth_rate_table)) * 100
missing_percentages
# Out:
# Регіон     0.000000
# 1950       7.142857
# 1960       3.571429
# 1970       3.571429
# 1990       0.000000
# 2000       0.000000
# 2012       0.000000
# 2014       7.142857
# 2019      14.285714
# dtype: float64

# %%
birth_rate_table = birth_rate_table[:-1]
birth_rate_table.shape
# Out:
# (27, 9)

# %%
numeric_columns = birth_rate_table.select_dtypes(include=[np.number]).columns
mean_values = birth_rate_table[numeric_columns].mean()
change_to_mean = birth_rate_table.loc[:, numeric_columns].fillna(mean_values)
birth_rate_table.loc[:, numeric_columns] = change_to_mean.round(1)
birth_rate_table
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6  11.1   8.0
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   8.0
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   8.0
# 12          Львівська  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13       Миколаївська  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14            Одеська  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15         Полтавська  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16         Рівненська  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17            Сумська  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18      Тернопільська  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19         Харківська  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20         Херсонська  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21        Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22          Черкаська  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23        Чернівецька  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24       Чернігівська  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25               Київ  23.1  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26        Севастополь  23.1  20.8  15.6  12.5   7.0  12.0  11.1   8.0

# %%
average_birth_rate_ukraine = birth_rate_table['2019'].mean()
high_birth_rate_regions = birth_rate_table[birth_rate_table['2019'] > average_birth_rate_ukraine]
high_birth_rate_regions_list = high_birth_rate_regions['Регіон'].tolist()
high_birth_rate_regions_list
# Out:
# ['Волинська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Львівська',
#  'Одеська',
#  'Рівненська',
#  'Херсонська',
#  'Чернівецька',
#  'Київ']

# %%
highest_birth_rate_region_2014 = birth_rate_table.loc[birth_rate_table['2014'].idxmax(), 'Регіон']
highest_birth_rate_region_2014
# Out:
# 'Рівненська'

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.transforms as transforms

sorted_birth_rates = birth_rate_table.sort_values(by='2019', ascending=False)

def gradient_bar(ax, x, y, width=0.8, bottom=0, **kwargs):
    cmap = LinearSegmentedColormap.from_list('blue_gradient', ['#00008B', '#ADD8E6'])
    norm = plt.Normalize(0, y)
    colors = cmap(norm(np.linspace(0, y, 256)))
    
    for i, color in enumerate(colors):
        rect = Rectangle((x - width/2, bottom + i*y/256), width, y/256, color=color, **kwargs)
        ax.add_patch(rect)

fig, ax = plt.subplots(figsize=(10, 6))

for idx, (region, rate) in enumerate(zip(sorted_birth_rates['Регіон'], sorted_birth_rates['2019'])):
    gradient_bar(ax, idx, rate)

ax.set_xticks(range(len(sorted_birth_rates['Регіон'])))
ax.set_xticklabels(sorted_birth_rates['Регіон'], rotation=90)
ax.set_xlim(-1, len(sorted_birth_rates['Регіон']))
ax.set_ylim(0, sorted_birth_rates['2019'].max()+1)
ax.set_title('Народжуваність в регіонах України в 2019 році')
ax.set_xlabel('Регіон')
ax.set_ylabel('Народжуваність')
ax.grid(axis='y', linestyle='--')

plt.tight_layout()
plt.show()

# %%
regions = birth_rate_table['Регіон'].tolist()

data_1950 = birth_rate_table['1950']
data_2019 = birth_rate_table['2019']

plt.figure(figsize=(10, 6))
plt.scatter(regions, data_1950, label='1950', color='blue')
plt.scatter(regions, data_2019, label='2019', color='red')

plt.title('Народжуваність в 1950 та 2019 роках')

plt.xlabel('Регіон')
plt.ylabel('Коефіцієнт народжуваності')
plt.xticks(rotation=90)

plt.legend()

plt.show()

# %%
years_columns = ['1950', '1960', '1970', '1990', '2000', '2012', '2014', '2019']
mean_birth_rates = birth_rate_table[years_columns].mean()
mean_birth_rate_table = pd.DataFrame(mean_birth_rates, columns=['avg'])

years = mean_birth_rate_table.index.tolist()
plt.figure(figsize=(10, 6))
plt.plot(years, mean_birth_rate_table, linestyle=':', marker='o', color='#34eb6e')

plt.title('Середня народжуваність за 1950 - 2019 роки')

plt.xlabel('Рік')
plt.ylabel('Середній коефіцієнт народжуваності')

plt.show()
